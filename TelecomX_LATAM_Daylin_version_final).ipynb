# %% [markdown]
# <a href="https://colab.research.google.com/github/daylincu2006/Amigo_Secreto/blob/main/TelecomX_LATAM_Daylin_version_final).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ## **Librerias**

# %%
import requests
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns

# %%
url='https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

resultado=requests.get(url)
datos_json = resultado.json()
df_clientes = pd.json_normalize(datos_json)
df_clientes
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
#Buscar los valores unicos de cada columna
print(f"La columna Churn contiene estos valores unicos: {df_clientes['Churn'].unique()}")
print(f"La columna customer.gender contiene estos valores unicos: {df_clientes['customer.gender'].unique()}")
print(f"La columna customer.Partner contiene estos valores unicos: {df_clientes['customer.Partner'].unique()}")
print(f"La columna customer.Dependents contiene estos valores unicos: {df_clientes['customer.Dependents'].unique()}")
print(f"La columna phone.PhoneService contiene estos valores unicos: {df_clientes['phone.PhoneService'].unique()}")
print(f"La columna phone.MultipleLines contiene estos valores unicos: {df_clientes['phone.MultipleLines'].unique()}")
print(f"La columna internet.InternetService contiene estos valores unicos: {df_clientes['internet.InternetService'].unique()}")
print(f"La columna internet.OnlineSecurity contiene estos valores unicos: {df_clientes['internet.OnlineSecurity'].unique()}")
print(f"La columna internet.OnlineBackup contiene estos valores unicos: {df_clientes['internet.OnlineBackup'].unique()}")
print(f"La columna internet.DeviceProtection contiene estos valores unicos: {df_clientes['internet.DeviceProtection'].unique()}")
print(f"La columna internet.TechSupport contiene estos valores unicos: {df_clientes['internet.TechSupport'].unique()}")
print(f"La columna internet.StreamingTV contiene estos valores unicos: {df_clientes['internet.StreamingTV'].unique()}")
print(f"La columna internet.StreamingMovies contiene estos valores unicos: {df_clientes['internet.StreamingMovies'].unique()}")
print(f"La columna account.PaperlessBilling contiene estos valores unicos: {df_clientes['account.PaperlessBilling'].unique()}")
print(f"La columna account.PaymentMethod contiene estos valores unicos: {df_clientes['account.PaymentMethod'].unique()}")
# Out:
# La columna Churn contiene estos valores unicos: ['No' 'Yes' '']
# La columna customer.gender contiene estos valores unicos: ['Female' 'Male']
# La columna customer.Partner contiene estos valores unicos: ['Yes' 'No']
# La columna customer.Dependents contiene estos valores unicos: ['Yes' 'No']
# La columna phone.PhoneService contiene estos valores unicos: ['Yes' 'No']
# La columna phone.MultipleLines contiene estos valores unicos: ['No' 'Yes' 'No phone service']
# La columna internet.InternetService contiene estos valores unicos: ['DSL' 'Fiber optic' 'No']
# La columna internet.OnlineSecurity contiene estos valores unicos: ['No' 'Yes' 'No internet service']
# La columna internet.OnlineBackup contiene estos valores unicos: ['Yes' 'No' 'No internet service']
# La columna internet.DeviceProtection contiene estos valores unicos: ['No' 'Yes' 'No internet service']
# La columna internet.TechSupport contiene estos valores unicos: ['Yes' 'No' 'No internet service']
# ...

# %% [markdown]
# #🔧 Transformación

# %%
#Remplazar los vacios por nan
df_clientes['Churn']=df_clientes['Churn'].replace('',np.nan)
df_clientes.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
# buscar valores nulos
print (df_clientes.isnull().sum())
# Out:
# customerID                     0
# Churn                        224
# customer.gender                0
# customer.SeniorCitizen         0
# customer.Partner               0
# customer.Dependents            0
# customer.tenure                0
# phone.PhoneService             0
# phone.MultipleLines            0
# internet.InternetService       0
# internet.OnlineSecurity        0
# internet.OnlineBackup          0
# internet.DeviceProtection      0
# internet.TechSupport           0
# internet.StreamingTV           0
# internet.StreamingMovies       0
# account.Contract               0
# account.PaperlessBilling       0
# account.PaymentMethod          0
# account.Charges.Monthly        0
# account.Charges.Total          0
# dtype: int64

# %%
#Eliminmo los valores nulo o vacios
df_clientes= df_clientes.dropna()

# %%
#verifico
print (df_clientes.isnull().sum())
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7043 non-null   object
#  1   Churn                      7043 non-null   object
#  2   customer.gender            7043 non-null   object
#  3   customer.SeniorCitizen     7043 non-null   int64
#  4   customer.Partner           7043 non-null   object
#  5   customer.Dependents        7043 non-null   object
#  6   customer.tenure            7043 non-null   int64
#  7   phone.PhoneService         7043 non-null   object
#  8   phone.MultipleLines        7043 non-null   object
#  9   internet.InternetService   7043 non-null   object
#  10  internet.OnlineSecurity    7043 non-null   object
#  11  internet.OnlineBackup      7043 non-null   object
#  12  internet.DeviceProtection  7043 non-null   object
# ...

# %%
df_clientes['account.Charges.Total'].astype(str)
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7043 non-null   object
#  1   Churn                      7043 non-null   object
#  2   customer.gender            7043 non-null   object
#  3   customer.SeniorCitizen     7043 non-null   int64
#  4   customer.Partner           7043 non-null   object
#  5   customer.Dependents        7043 non-null   object
#  6   customer.tenure            7043 non-null   int64
#  7   phone.PhoneService         7043 non-null   object
#  8   phone.MultipleLines        7043 non-null   object
#  9   internet.InternetService   7043 non-null   object
#  10  internet.OnlineSecurity    7043 non-null   object
#  11  internet.OnlineBackup      7043 non-null   object
#  12  internet.DeviceProtection  7043 non-null   object
# ...

# %%
#Convertimos los datos vacios a nan
df_clientes.loc[:, 'account.Charges.Total'] = df_clientes['account.Charges.Total'].replace(' ', np.nan)

# %%
print (df_clientes.isnull().sum())
# Out:
# customerID                    0
# Churn                         0
# customer.gender               0
# customer.SeniorCitizen        0
# customer.Partner              0
# customer.Dependents           0
# customer.tenure               0
# phone.PhoneService            0
# phone.MultipleLines           0
# internet.InternetService      0
# internet.OnlineSecurity       0
# internet.OnlineBackup         0
# internet.DeviceProtection     0
# internet.TechSupport          0
# internet.StreamingTV          0
# internet.StreamingMovies      0
# account.Contract              0
# account.PaperlessBilling      0
# account.PaymentMethod         0
# account.Charges.Monthly       0
# account.Charges.Total        11
# dtype: int64

# %%
#Eliminar los nulos o Nan y Convertir a Float
df_clientes.loc[:, 'account.Charges.Total'] = pd.to_numeric(df_clientes.loc[:, 'account.Charges.Total'], errors='coerce')
#df_clientes['account.Charges.Total'] = pd.to_numeric(df_clientes['account.Charges.Total'], errors='coerce')

#Eliminmo los valores nulo o vacios
print (df_clientes.isnull().sum())
df_clientes.info()
# Out:
# customerID                    0
# Churn                         0
# customer.gender               0
# customer.SeniorCitizen        0
# customer.Partner              0
# customer.Dependents           0
# customer.tenure               0
# phone.PhoneService            0
# phone.MultipleLines           0
# internet.InternetService      0
# internet.OnlineSecurity       0
# internet.OnlineBackup         0
# internet.DeviceProtection     0
# internet.TechSupport          0
# internet.StreamingTV          0
# internet.StreamingMovies      0
# account.Contract              0
# account.PaperlessBilling      0
# account.PaymentMethod         0
# account.Charges.Monthly       0
# account.Charges.Total        11
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
# ...

# %%
#remplazar mayuscula por minuscula
df_clientes['customer.gender'] = df_clientes['customer.gender'].str.lower()
df_clientes['phone.MultipleLines'] = df_clientes['phone.MultipleLines'].str.lower()
df_clientes['internet.InternetService'] = df_clientes['internet.InternetService'].str.lower()
df_clientes['internet.OnlineSecurity'] = df_clientes['internet.OnlineSecurity'].str.lower()
df_clientes['internet.OnlineBackup'] = df_clientes['internet.OnlineBackup'].str.lower()
df_clientes['internet.DeviceProtection'] = df_clientes['internet.DeviceProtection'].str.lower()
df_clientes['internet.TechSupport'] = df_clientes['internet.TechSupport'].str.lower()
df_clientes['account.Contract'] = df_clientes['account.Contract'].str.lower()
df_clientes['account.PaymentMethod'] = df_clientes['account.PaymentMethod'].str.lower()
# Out:
# /tmp/ipython-input-930913196.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clientes['customer.gender'] = df_clientes['customer.gender'].str.lower()
# /tmp/ipython-input-930913196.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clientes['phone.MultipleLines'] = df_clientes['phone.MultipleLines'].str.lower()
# /tmp/ipython-input-930913196.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Verifico valores únicos en las columnas usando df_clientes
print(f"La columna Churn contiene estos valores unicos: {df_clientes['Churn'].unique()}")
print(f"La columna customer.gender contiene estos valores unicos: {df_clientes['customer.gender'].unique()}")
print(f"La columna customer.Partner contiene estos valores unicos: {df_clientes['customer.Partner'].unique()}")
print(f"La columna customer.Dependents contiene estos valores unicos: {df_clientes['customer.Dependents'].unique()}")
print(f"La columna phone.PhoneService contiene estos valores unicos: {df_clientes['phone.PhoneService'].unique()}")
print(f"La columna phone.MultipleLines contiene estos valores unicos: {df_clientes['phone.MultipleLines'].unique()}")
print(f"La columna internet.InternetService contiene estos valores unicos: {df_clientes['internet.InternetService'].unique()}")
print(f"La columna internet.OnlineSecurity contiene estos valores unicos: {df_clientes['internet.OnlineSecurity'].unique()}")
print(f"La columna internet.OnlineBackup contiene estos valores unicos: {df_clientes['internet.OnlineBackup'].unique()}")
print(f"La columna internet.DeviceProtection contiene estos valores unicos: {df_clientes['internet.DeviceProtection'].unique()}")
print(f"La columna internet.TechSupport contiene estos valores unicos: {df_clientes['internet.TechSupport'].unique()}")
print(f"La columna internet.StreamingTV contiene estos valores unicos: {df_clientes['internet.StreamingTV'].unique()}")
print(f"La columna internet.StreamingMovies contiene estos valores unicos: {df_clientes['internet.StreamingMovies'].unique()}")
print(f"La columna account.PaperlessBilling contiene estos valores unicos: {df_clientes['account.PaperlessBilling'].unique()}")
print(f"La columna account.PaymentMethod contiene estos valores unicos: {df_clientes['account.PaymentMethod'].unique()}")
print(f"La columna account.Contract contiene estos valores unicos: {df_clientes['account.Contract'].unique()}")
# Out:
# La columna Churn contiene estos valores unicos: ['No' 'Yes']
# La columna customer.gender contiene estos valores unicos: ['female' 'male']
# La columna customer.Partner contiene estos valores unicos: ['Yes' 'No']
# La columna customer.Dependents contiene estos valores unicos: ['Yes' 'No']
# La columna phone.PhoneService contiene estos valores unicos: ['Yes' 'No']
# La columna phone.MultipleLines contiene estos valores unicos: ['no' 'yes' 'no phone service']
# La columna internet.InternetService contiene estos valores unicos: ['dsl' 'fiber optic' 'no']
# La columna internet.OnlineSecurity contiene estos valores unicos: ['no' 'yes' 'no internet service']
# La columna internet.OnlineBackup contiene estos valores unicos: ['yes' 'no' 'no internet service']
# La columna internet.DeviceProtection contiene estos valores unicos: ['no' 'yes' 'no internet service']
# La columna internet.TechSupport contiene estos valores unicos: ['yes' 'no' 'no internet service']
# ...

# %%
#Convirtiendo a binario
df_clientes.loc[:, 'Churn'] = df_clientes['Churn'].str.lower()
df_clientes.loc[:, 'Churn'] = df_clientes['Churn'].replace({'yes':'1', 'no':'0'})
df_clientes.loc[:, 'customer.Partner'] = df_clientes['customer.Partner'].str.lower()
df_clientes.loc[:, 'customer.Partner'] = df_clientes['customer.Partner'].replace({'yes':'1', 'no':'0'})
df_clientes.loc[:, 'customer.Dependents'] = df_clientes['customer.Dependents'].str.lower()
df_clientes.loc[:, 'customer.Dependents'] = df_clientes['customer.Dependents'].replace({'yes':'1', 'no':'0'})
df_clientes.loc[:, 'phone.PhoneService'] = df_clientes['phone.PhoneService'].str.lower()
df_clientes.loc[:, 'phone.PhoneService'] = df_clientes['phone.PhoneService'].replace({'yes':'1', 'no':'0'})
df_clientes.loc[:, 'account.PaperlessBilling'] = df_clientes['account.PaperlessBilling'].str.lower()
df_clientes.loc[:, 'account.PaperlessBilling'] = df_clientes['account.PaperlessBilling'].replace({'yes':'1', 'no':'0'})

# %%
df_clientes
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO     0          female                       0
# 1     0003-MKNFE     0            male                       0
# 2     0004-TLHLJ     1            male                       0
# 3     0011-IGKFF     1            male                       1
# 4     0013-EXCHZ     1          female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD     0          female                       0
# 7263  9992-RRAMN     1            male                       0
# 7264  9992-UJOEL     0            male                       0
# 7265  9993-LHIEB     0            male                       0
# 7266  9995-HOTOH     0            male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                   1                   1                9                  1
# ...

# %%
# Verifico valores únicos en las columnas usando df_clientes
print(f"La columna Churn contiene estos valores unicos: {df_clientes['Churn'].unique()}")
print(f"La columna customer.gender contiene estos valores unicos: {df_clientes['customer.gender'].unique()}")
print(f"La columna customer.Partner contiene estos valores unicos: {df_clientes['customer.Partner'].unique()}")
print(f"La columna customer.Dependents contiene estos valores unicos: {df_clientes['customer.Dependents'].unique()}")
print(f"La columna phone.PhoneService contiene estos valores unicos: {df_clientes['phone.PhoneService'].unique()}")
print(f"La columna phone.MultipleLines contiene estos valores unicos: {df_clientes['phone.MultipleLines'].unique()}")
print(f"La columna internet.InternetService contiene estos valores unicos: {df_clientes['internet.InternetService'].unique()}")
print(f"La columna internet.OnlineSecurity contiene estos valores unicos: {df_clientes['internet.OnlineSecurity'].unique()}")
print(f"La columna internet.OnlineBackup contiene estos valores unicos: {df_clientes['internet.OnlineBackup'].unique()}")
print(f"La columna internet.DeviceProtection contiene estos valores unicos: {df_clientes['internet.DeviceProtection'].unique()}")
print(f"La columna internet.TechSupport contiene estos valores unicos: {df_clientes['internet.TechSupport'].unique()}")
print(f"La columna internet.StreamingTV contiene estos valores unicos: {df_clientes['internet.StreamingTV'].unique()}")
print(f"La columna internet.StreamingMovies contiene estos valores unicos: {df_clientes['internet.StreamingMovies'].unique()}")
print(f"La columna account.PaperlessBilling contiene estos valores unicos: {df_clientes['account.PaperlessBilling'].unique()}")
# Out:
# La columna Churn contiene estos valores unicos: ['0' '1']
# La columna customer.gender contiene estos valores unicos: ['female' 'male']
# La columna customer.Partner contiene estos valores unicos: ['1' '0']
# La columna customer.Dependents contiene estos valores unicos: ['1' '0']
# La columna phone.PhoneService contiene estos valores unicos: ['1' '0']
# La columna phone.MultipleLines contiene estos valores unicos: ['no' 'yes' 'no phone service']
# La columna internet.InternetService contiene estos valores unicos: ['dsl' 'fiber optic' 'no']
# La columna internet.OnlineSecurity contiene estos valores unicos: ['no' 'yes' 'no internet service']
# La columna internet.OnlineBackup contiene estos valores unicos: ['yes' 'no' 'no internet service']
# La columna internet.DeviceProtection contiene estos valores unicos: ['no' 'yes' 'no internet service']
# La columna internet.TechSupport contiene estos valores unicos: ['yes' 'no' 'no internet service']
# ...

# %%
#Verificacion de duplicados
duplicados= df_clientes.duplicated().sum()
print(duplicados)
# Out:
# 0

# %%
#Agrego la Columna Ingresos Diarios
df_clientes.loc[:,'Ingresos_Diarios']= df_clientes['account.Charges.Monthly']/30
df_clientes.head(3)
# Out:
# /tmp/ipython-input-69276386.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clientes.loc[:,'Ingresos_Diarios']= df_clientes['account.Charges.Monthly']/30
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO     0          female                       0                1
# 1  0003-MKNFE     0            male                       0                0
# 2  0004-TLHLJ     1            male                       0                0
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                   1                9                  1                  no
# 1                   0                9                  1                 yes
# ...

# %%
df_clientes['account.PaymentMethod'] = df_clientes['account.PaymentMethod'].map({
    'mailed check': 1,
    'electronic check': 2,
    'credit card (automatic)': 3,
    'bank transfer (automatic)': 4})
df_clientes['account.PaymentMethod']
# Out:
# /tmp/ipython-input-2366304815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clientes['account.PaymentMethod'] = df_clientes['account.PaymentMethod'].map({
# 0       1
# 1       1
# 2       2
# 3       2
# 4       1
#        ..
# 7262    1
# 7263    2
# 7264    1
# 7265    1
# 7266    2
# Name: account.PaymentMethod, Length: 7043, dtype: int64

# %%
df_clientes['account.Contract'] = df_clientes['account.Contract'].map({
    'one year': 1,
    'two year': 2,
    'month-to-month': 3})
df_clientes['account.Contract']
# Out:
# /tmp/ipython-input-3780091391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clientes['account.Contract'] = df_clientes['account.Contract'].map({
# 0       1
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 7262    1
# 7263    3
# 7264    3
# 7265    2
# 7266    2
# Name: account.Contract, Length: 7043, dtype: int64

# %% [markdown]
# #📊 Carga y análisis

# %%
df_clientes.describe()
# Out:
#        customer.SeniorCitizen  customer.tenure  account.Contract  \
# count             7043.000000      7043.000000       7043.000000
# mean                 0.162147        32.371149          2.341048
# std                  0.368612        24.559481          0.801943
# min                  0.000000         0.000000          1.000000
# 25%                  0.000000         9.000000          2.000000
# 50%                  0.000000        29.000000          3.000000
# 75%                  0.000000        55.000000          3.000000
# max                  1.000000        72.000000          3.000000
#
#        account.PaymentMethod  account.Charges.Monthly  Ingresos_Diarios
# count            7043.000000              7043.000000       7043.000000
# mean                2.425671                64.761692          2.158723
# std                 1.068104                30.090047          1.003002
# min                 1.000000                18.250000          0.608333
# ...

# %%
df_churn =df_Churn['Churn'].value_counts()
df_churn

# %%
# Crear un diccionario con los conteos
datos = {
    'Permanecieron': [5174],
    'Cancelaron': [1869],
     'Nulos': [224]
}

# Convertir el diccionario en un DataFrame
df_evasion = pd.DataFrame(datos)

# Mostrar la tabla resumen
print(df_evasion)
# Out:
#    Permanecieron  Cancelaron  Nulos
# 0           5174        1869    224

# %%
import matplotlib.pyplot as plt
# Cambio de formato para graficar
df_resumen = df_evasion.melt(var_name='Estado', value_name='Cantidad')
print(df_resumen)

plt.figure(figsize=(8,6))
sns.barplot(x='Estado', y='Cantidad', data=df_resumen, color='g')
plt.title('Distribución de cancelaciones por clientes')
plt.ylabel('Cantidad')
plt.xlabel('Estado')
plt.show()
# Out:
#           Estado  Cantidad
# 0  Permanecieron      5174
# 1     Cancelaron      1869
# 2          Nulos       224

# %%
# Crear un nuevo DataFrame con columnas específicas
df_Churn = df_clientes[['Churn', 'customer.gender']]
df_Churn

# Mostrar el nuevo DataFrame
print(df_Churn)
# Out:
#      Churn customer.gender
# 0        0          female
# 1        0            male
# 2        1            male
# 3        1            male
# 4        1          female
# ...    ...             ...
# 7262     0          female
# 7263     1            male
# 7264     0            male
# 7265     0            male
# 7266     0            male
#
# [7043 rows x 2 columns]

# %%
# Agrupa por género y cuenta el número de clientes en cada grupo
df_grouped = df_Churn.groupby('customer.gender').size().reset_index(name='total_clients')
df_grouped
# Out:
#   customer.gender  total_clients
# 0          female           3488
# 1            male           3555

# %%
# Agrupar por género y calcular la proporción de churn
df_churn_by_gender =round(df_Churn.groupby('customer.gender')['Churn'].value_counts(normalize=True).unstack()*100,1)
df_churn_by_gender
# Out:
# Churn               0     1
# customer.gender
# female           73.1  26.9
# male             73.8  26.2

# %%
# Cancelaciones por genero
plt.figure(figsize=(8,5))


sns.countplot(data=df_Churn, x="customer.gender", hue="Churn", palette="tab10")
plt.title("Cancelación por genero")
plt.ylabel("Clientes")
plt.xlabel("")
plt.xticks(rotation=10)
plt.show()

# %%
# 2.Crear un nuevo DataFrame con columnas específicas
df_tipo_contrato = df_clientes[['Churn', 'account.Contract']]
df_tipo_contrato

# Mostrar el nuevo DataFrame
print(df_tipo_contrato)
# Out:
#      Churn  account.Contract
# 0        0                 1
# 1        0                 3
# 2        1                 3
# 3        1                 3
# 4        1                 3
# ...    ...               ...
# 7262     0                 1
# 7263     1                 3
# 7264     0                 3
# 7265     0                 2
# 7266     0                 2
#
# [7043 rows x 2 columns]

# %%
# Agrupar los datos por tipo de contrato y churn
counts = df_tipo_contrato.groupby(['account.Contract', 'Churn']).size().unstack()

# Opcional: renombrar las categorías para mayor claridad
# counts.columns = ['No Churn', 'Churn']  # si es necesario, dependiendo de los valores en 'Churn'

# Crear gráfico de barras apiladas
ax = counts.plot(kind='bar', stacked=True, colormap='Set2', figsize=(10,6))

# Añadir títulos y etiquetas
ax.set_title('Distribución del Churn según Tipo de Contrato')
ax.set_xlabel('Tipo de Contrato')
ax.set_ylabel('Cantidad de Clientes')
ax.legend(title='Churn')

plt.xticks(rotation=0)
plt.show()

# %%
# 3.Crear un nuevo DataFrame con columnas específicas
df_metodo_pago = df_clientes[['Churn', 'account.PaymentMethod']]
df_metodo_pago

# Mostrar el nuevo DataFrame
print(df_metodo_pago)
# Out:
#      Churn  account.PaymentMethod
# 0        0                      1
# 1        0                      1
# 2        1                      2
# 3        1                      2
# 4        1                      1
# ...    ...                    ...
# 7262     0                      1
# 7263     1                      2
# 7264     0                      1
# 7265     0                      1
# 7266     0                      2
#
# [7043 rows x 2 columns]

# %%
# Agrupar y contar
proporciones = df_metodo_pago.groupby(['account.PaymentMethod', 'Churn']).size().reset_index(name='counts')

# Calcular totales por método de pago
totales = df_metodo_pago.groupby('account.PaymentMethod').size().reset_index(name='total')

# Unir para calcular porcentajes
proporciones = proporciones.merge(totales, on='account.PaymentMethod')
proporciones['percentage'] = (proporciones['counts'] / proporciones['total']) * 100

# Visualizar con seaborn
sns.barplot(
    data=proporciones,
    x='account.PaymentMethod',
    y='percentage',
    hue='Churn'
)

plt.title('Proporción de Churn por Método de Pago')
plt.xlabel('Método de Pago')
plt.ylabel('Porcentaje (%)')
plt.xticks(rotation=45)

plt.show()

# %%
# 4.Crear un nuevo DataFrame con columnas específicas
df_permanencia = df_clientes[['Churn', 'customer.tenure','account.Charges.Monthly']]
df_permanencia

# Mostrar el nuevo DataFrame
print(df_permanencia)
# Out:
#      Churn  customer.tenure
# 0        0                9
# 1        0                9
# 2        1                4
# 3        1               13
# 4        1                3
# ...    ...              ...
# 7262     0               13
# 7263     1               22
# 7264     0                2
# 7265     0               67
# 7266     0               63
#
# [7043 rows x 2 columns]

# %%
# Crear rangos de permanencia
bins = [0, 12, 24, 36, 48, 60, np.inf]
labels = ['0-12', '13-24', '25-36', '37-48', '49-60', 'más de 60']
df_permanencia['tenure_range'] = pd.cut(df_permanencia['customer.tenure'], bins=bins, labels=labels)

# Contar por rango y churn
counts = df_permanencia.groupby(['tenure_range', 'Churn']).size().unstack()

# Plotear con estilo atractivo
ax = counts.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10,6))
ax.set_title('Clientes según rango de permanencia y churn')
ax.set_xlabel('Rango de permanencia (meses)')
ax.set_ylabel('Cantidad de clientes')
plt.xticks(rotation=45)
plt.legend(title='Churn')
plt.show()
# Out:
# /tmp/ipython-input-1321439482.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permanencia['tenure_range'] = pd.cut(df_permanencia['customer.tenure'], bins=bins, labels=labels)
# /tmp/ipython-input-1321439482.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = df_permanencia.groupby(['tenure_range', 'Churn']).size().unstack()

# %%
# 5.Crear un nuevo DataFrame con columnas específicas para encontrar la evasion
df_escape = df_clientes[['Churn', 'customer.tenure','account.Charges.Total']]
df_escape

# Mostrar el nuevo DataFrame
print(df_escape)
# Out:
#      Churn  customer.tenure account.Charges.Total
# 0        0                9                 593.3
# 1        0                9                 542.4
# 2        1                4                280.85
# 3        1               13               1237.85
# 4        1                3                 267.4
# ...    ...              ...                   ...
# 7262     0               13                 742.9
# 7263     1               22                1873.7
# 7264     0                2                 92.75
# 7265     0               67               4627.65
# 7266     0               63                3707.6
#
# [7043 rows x 3 columns]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df_escape,
    x='customer.tenure',
    y='account.Charges.Total',
    hue='Churn',
    palette='Set1',
    alpha=0.7,
    s=100
)

plt.title('Permanencia vs Cargos Totales por Churn')
plt.xlabel('Tiempo de permanencia (meses)')
plt.ylabel('Cargos Totales')
plt.legend(title='Churn')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x='Churn',
    y='customer.tenure',
    data=df_escape,
    palette='Set1'
)

plt.title('Distribución de Tiempo de Permanencia según Churn')
plt.xlabel('Churn')
plt.ylabel('Tiempo de permanencia (meses)')
plt.show()
# Out:
# /tmp/ipython-input-1314824163.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x='Churn',
    y='account.Charges.Total',
    data=df_escape,
    palette='Set2'
)

plt.title('Distribución de Cargos Totales según Churn')
plt.xlabel('Churn')
plt.ylabel('Cargos Totales')
plt.show()
# Out:
# /tmp/ipython-input-1024629545.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# 5.Crear un nuevo DataFrame con columnas específicas para encontrar la evasion
# Crear el DataFrame con las columnas específicas
df_cargos_por_cancelacion = df_clientes[['Churn', 'customer.tenure', 'account.Charges.Monthly']]

# Mostrar el DataFrame
print(df_cargos_por_cancelacion)
# Out:
#      Churn  customer.tenure  account.Charges.Monthly
# 0        0                9                    65.60
# 1        0                9                    59.90
# 2        1                4                    73.90
# 3        1               13                    98.00
# 4        1                3                    83.90
# ...    ...              ...                      ...
# 7262     0               13                    55.15
# 7263     1               22                    85.10
# 7264     0                2                    50.30
# 7265     0               67                    67.85
# 7266     0               63                    59.00
#
# [7043 rows x 3 columns]

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x='Churn',
    y='customer.tenure',
    data=df_cargos_por_cancelacion,
    palette='Set1'
)

plt.title('Tiempo de Permanencia según Churn')
plt.xlabel('Churn')
plt.ylabel('Tiempo de Permanencia (meses)')
plt.show()
# Out:
# /tmp/ipython-input-2466269621.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x='Churn',
    y='account.Charges.Monthly',
    data=df_cargos_por_cancelacion,
    palette='Set2'
)

plt.title('Cargos Mensuales según Churn')
plt.xlabel('Churn')
plt.ylabel('Cargos Mensuales')
plt.show()
# Out:
# /tmp/ipython-input-1415874233.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# #📄Informe final
